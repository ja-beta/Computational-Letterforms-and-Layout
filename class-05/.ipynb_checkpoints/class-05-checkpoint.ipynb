# %%
# %%html --isolated
# <style>
#     h1{
#         font-size: 96px;
#         color: red;
#         margin-bottom: 0;
#     }
#
#     .test-class{
#         display: flex;
#         gap: 8px;
#         align-items: center;
#     }
#
#     .dot{
#         width: 8px;
#         height: 8px;
#         background-color: red;
#         border-radius: 50%;
#     }
# </style>
# <h1>Howdy there!</h1>
# <div class="test-class">
#     <p> this is one p</p>
#     <div class="dot"></div>
#     <p> this is another one</p>
# </div>
# Out:
# <style>
#     h1{
#         font-size: 96px;
#         color: red;
#         margin-bottom: 0;
#     }
#
#     .test-class{
#         display: flex;
#         gap: 8px;
#         align-items: center;
#     }
#
#     .dot{
#         width: 8px;
#         height: 8px;
#         background-color: red;
#         border-radius: 50%;
#     }
# </style>
# <h1>Howdy there!</h1>
# <div class="test-class">
#     <p> this is one p</p>
#     <div class="dot"></div>
#     <p> this is another one</p>
# </div>
