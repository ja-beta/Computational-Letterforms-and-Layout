# %%
import random
import math
from IPython.display import display, HTML
import base64
def show_html(src):
    return display(HTML(src), metadata=dict(isolated=True))

# %% [markdown]
# # Custom fonts!

# %% [markdown]
# All the automating opportunities last class made me think of all the "annoying" parts of css that one usually has to go through, like importing fonts, so this seems like a nice opportunity to have it generate the "@font-face" css code that I would usually need to manually type by hand. There are probably smarter ways of doing this but I don't like abstracting everything and would like to retain some control so I'm going with a function that just goes through a list of fonts files (that I have just included in my project folder), and generates the appropriate css import rules for each one.

# %%
def get_fonts_css(fonts):
    css = ""
    for name, path, weight, style in fonts:
        with open(path, 'rb') as f:
            font_data = f.read()
        base64_font = base64.b64encode(font_data).decode('utf-8')
        css += f"""
        @font-face {{
            font-family: '{name}';
            src: url(data:font/opentype;base64,{base64_font}) format('opentype');
            font-weight: {weight};
            font-style: {style};
        }}
        """
    return css

# %% [markdown]
# Fonts are binary data - so if we want to embed it directly in HTML/CSS, we need to convert the binary data into text (like a string of ASCII characters) that can be included in the source code. Base64 encoding is a standardized way of doing it (or so I've learned). It meand it's essentially a string of 64 ASCII characters.
# From my experience / understanding this would not be the best approach for actual sites as it drastically increases the weight of the HTML file (as it's embedded in it), but this might be the way to go for our porpuses here, where I'd rather have something reliable that I can easily share.

# %%
font_files = [
    ('80-kb-g', './fonts/80-kb-Grunge.otf', '400', 'normal'),
    ('80-kb', './fonts/80-kb-Sharp.otf', '400', 'normal'),
    ('80-kb', './fonts/80-kb-SharpBold.otf', '600', 'bold'),
    ('80-kb', './fonts/80-kb-SharpBoldItalic.otf', '600', 'italic'),
    ('80-kb', './fonts/80-kb-SharpItalic.otf', '400', 'italic'),
    ('80-kb-s', './fonts/80-kb-Soft.otf', '400', 'normal')
]

# %%
css = get_fonts_css(font_files)

# %%
html_tmpl = """<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="utf-8">
    <title>{title}</title>
    <style>
    html {{ 
        min-height: 5em; 
        overflow: hidden;
        font-family: '80-kb', monospace;
        font-size: 18px;
        }}

    body{{
        background-color: transparent;
    }}

    h1 {{
        font-weight: 400;
    }}

    div{{
        background-color: transparent;
    }}
    </style>
</head>
<body>
{content}
</body>
</html>"""

# %%
#...and let's just quickly test that it works:
test = html_tmpl.format(title="My first HTML page", content="<p>This is a test!</p>")
show_html(test)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>My first HTML page</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <p>This is a test!</p>
# </body>
# </html>

# %%
def mkdiv(content, **kwargs):
    if 'position' not in kwargs:
        kwargs['position'] = 'absolute'
    style_str = ' '.join([": ".join((k.replace('_', '-'), v))+";" for k, v in kwargs.items()])
    return f"<div style='{style_str}'>{content}</div>"

# %% [markdown]
# # Texts
# I'm going to work with quotes I've extracted from news articles. The process of extracting the quotes is part of my thesis and is fully automated, however for this particular exercise I intend to manually select some that I think could be good to work with.

# %%
q0 = 'You feel like you can breathe again'
print(q0)
# Out:
# You feel like you can breathe again

# %%
breathe = mkdiv(q0,
                top= "10px")
html_src = html_tmpl.format(title="breathe_again", content=breathe)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>breathe_again</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <div style='top: 10px; position: absolute;'>You feel like you can breathe again</div>
# </body>
# </html>

# %%
words = q0.split()
before_again = ' '.join(words[:-1])
again_w = words[-1]
print(before_again, again_w)
# Out:
# You feel like you can breathe again

# %%
import math

# %%
elements = []

elements.append(mkdiv(before_again, 
                     position="absolute", 
                     top="78px",
                     left="48%",
                     font_size="12px",
                     transform="translate(-50%, -50%)",
                     z_index="1",
                     color="white"
                     )
               )


repetitions = 80
max_space = 12

for i in range(repetitions):
    if i < repetitions / 20: # for the first x percent (100/x=%), the space increases as i increases
        space_factor = i / (repetitions / 3) * max_space
    else: # for the remaining, the space decreases as i increases
        space_factor = (repetitions - i) / (repetitions / 3) * max_space
    
    spaced_again = ""
    for char in again_w:
        spaced_again += char + "&nbsp;" * int(space_factor)
    
    #calculates the percentage of the way through the repetitions
    t = i / repetitions  
    
    left_pos = 60 
    
    # Parabolic arc - the formula 2*t*(1-t) creates a curve that rises and falls
    top_pos = 72 + 1200 * (2 * t * (1-t))

    opacity = 0.1 + 0.6 * (i / repetitions)
    
    elements.append(mkdiv(
        spaced_again, 
        position="absolute", 
        left=f"{left_pos}%",  
        transform="translateX(-50%)", 
        top=f"{top_pos}px",
        opacity= "1",
        font_size="12px",
        background_color="transparent",
        color="white",
    ))


poem_content = "".join(elements)
container_div = f"""
<div style="position: relative; 
            margin: 10px; 
            min-height: 800px;
            background-color: black;
            
            ">{poem_content}
</div>"""
html_src = html_tmpl.format(title="again", content=container_div)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>again</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
#
# <div style="position: relative;
#             margin: 10px;
#             min-height: 800px;
#             background-color: black;
#
# ...

# %%
elements = []

repetitions = 78
max_space = 9

for i in range(repetitions):
    if i < repetitions / 25: # for the first x percent (100/x=%), the space increases as i increases
        space_factor = i / (repetitions / 4) * max_space
    else: # for the remaining, the space decreases as i increases
        space_factor = (repetitions - i) / (repetitions / 4) * max_space
    
    spaced_again = ""
    for char in "have this yo-yo experience once again":
        spaced_again += char + "&nbsp;" * int(space_factor)
    
    #calculates the percentage of the way through the repetitions
    t = i / repetitions  
    
    left_pos = 53
    
    # Parabolic arc - the formula 2*t*(1-t) - I used Claude and asked for a formula that creates a curve that rises and falls
    top_pos = 72 + 1200 * (2 * t * (1-t))
    
    elements.append(mkdiv(
        spaced_again, 
        position="absolute", 
        left=f"{left_pos}%",  
        transform="translateX(-50%)", 
        top=f"{top_pos}px",
        opacity= "1",
        font_size="12px",
        background_color="transparent",
        color="#838383",
        overflow="hidden"
    ))


poem_content = "".join(elements)
container_div = f"""
<div style="position: relative; 
            margin: 10px; 
            min-height: 800px;
            background-color: gainsboro;
            overflow: hidden;
            
            ">{poem_content}
</div>"""
html_src = html_tmpl.format(title="again", content=container_div)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>again</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
#
# <div style="position: relative;
#             margin: 10px;
#             min-height: 800px;
#             background-color: gainsboro;
#             overflow: hidden;
#
# ...

# %%
q1 = "these were matters of life and death"

matters = mkdiv(q1,
                top= "10px",
                background_color= "white"
                )
html_src = html_tmpl.format(title="matters", content=matters)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>matters</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <div style='top: 10px; background-color: white; position: absolute;'>these were matters of life and death</div>
# </body>
# </html>

# %%
words = q1.split()
elements = []
variations = []

#creating a list of all the variations of the sentence
for i in range(len(words)):
    rotated_words = words[i:] + words[:i]
    variations.append(" ".join(rotated_words))

vertical_spacing = 32
start_y = 120

container = """position: relative; 
                    margin: 40px; 
                    min-height: 500px;
                    background-color: white;"""

for idx, sentence in enumerate(variations): #enumerate is like a for loop but it also gives us the index of each item so we can use it for spaacing
    elements.append(mkdiv(
        sentence,
        position="absolute",
        left="50%",
        top=f"{start_y + idx * vertical_spacing}px",
        transform="translateX(-50%)",
        color="black",
        font_size="16px",
        letter_spacing="-0.5px"
    ))

poem_content = "".join(elements)
div = f"<div style='{container}'>{poem_content}</div>"
html_src = html_tmpl.format(title="matters", content=div)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>matters</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <div style='position: relative;
#                     margin: 40px;
#                     min-height: 500px;
# ...

# %%
#Initialy I just wanted to add the first sentence again at the end (this was just a "+1" in the for loop to just run another rotation), but then decided to instead also add more repetitions
words = q1.split()
elements = []

base_variations = []
for i in range(len(words)):
    rotated_words = words[i:] + words[:i]
    base_variations.append(" ".join(rotated_words))

repetitions = 3 
variations = []
for r in range(repetitions):
    variations.extend(base_variations) #extend is like append but it adds the entire list to the end of the other list, while append adds the list as an item by itself

vertical_spacing = 14
start_y = 100

container = """position: relative; 
                    margin: 40px; 
                    min-height: 600px;
                    background-color: black;"""

for idx, sentence in enumerate(variations):
    elements.append(mkdiv(
        sentence,
        position="absolute",
        left="50%",
        top=f"{start_y + idx * vertical_spacing}px",
        transform="translateX(-50%)",
        color="gainsboro",
        font_size="12px",
        letter_spacing="-0.5px",
        font_family="80-kb-g",
        background_color="transparent",
    ))

poem_content = "".join(elements)
div = f"<div style='{container}'>{poem_content}</div>"
html_src = html_tmpl.format(title="matters", content=div)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>matters</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <div style='position: relative;
#                     margin: 40px;
#                     min-height: 600px;
# ...

# %%
words = q1.split()
elements = []

base_variations = []
for i in range(len(words)+1):
    rotated_words = words[i:] + words[:i]
    base_variations.append(" ".join(rotated_words))

repetitions = 3 
variations = []
for r in range(repetitions):
    variations.extend(base_variations)

center_idx = len(variations) // 2 # finds the middle index of the list in int
max_words = len(words)

vertical_spacing = 24
start_y = 100

container = """position: relative; 
            margin: 40px; 
            min-height: 750px;
            background-color: gainsboro;"""

for idx, sentence in enumerate(variations):
    distance_from_center = abs(idx - center_idx) / (len(variations) / 2)
    
    words_to_remove = int(max_words * 0.92 * (distance_from_center ** 1))
    
    words_to_keep = max(1, max_words - words_to_remove)
    
    words_in_sentence = sentence.split()
    truncated_sentence = " ".join(words_in_sentence[:words_to_keep])
    
    elements.append(mkdiv(
        truncated_sentence,
        position="absolute",
        left="50%",
        top=f"{start_y + idx * vertical_spacing}px",
        transform="translateX(-50%)",
        color="gainsboro",
        font_size="13px",
        letter_spacing="2px",
        font_family="80-kb-g",
        background_color="#686868",
        padding="2px 4px"
    ))

poem_content = "".join(elements)
div = f"<div style='{container}'>{poem_content}</div>"
html_src = html_tmpl.format(title="matters", content=div)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>matters</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <div style='position: relative;
#             margin: 40px;
#             min-height: 750px;
# ...

# %%
words = q1.split()
elements = []

base_variations = []
for i in range(len(words)):
    rotated_words = words[i:] + words[:i]
    base_variations.append(" ".join(rotated_words))

repetitions = 3
variations = []
for r in range(repetitions):
    variations.extend(base_variations)

center_idx = len(variations) // 2
max_words = len(words)

vertical_spacing = 18
start_y = 100

container = """position: relative; 
            margin: 40px; 
            min-height: 750px;
            background-color: #E7DAD4;"""

for idx, sentence in enumerate(variations):
    distance_from_center = abs(idx - center_idx) / (len(variations) / 2)
    
    words_to_remove = int(max_words * 3 * (distance_from_center ** 1.5))
    
    words_to_keep = max(1, max_words - words_to_remove)
    
    words_in_sentence = sentence.split()
    truncated_sentence = " ".join(words_in_sentence[:words_to_keep])
    
    elements.append(mkdiv(
        truncated_sentence,
        position="absolute",
        left="50%",
        top=f"{start_y + idx * vertical_spacing + random.randint(-16, 16)}px",
        transform="translateX(-50%)",
        color="#70704D",
        font_size="21px",
        letter_spacing="2px",
        text_align="center",
        font_family="80-kb-g",
        padding="2px 4px",
        text_shadow= "0 0 64px #FF4916, 0 0 32px #FF4916, 0 0 8px #FF4916",
        mix_blend_mode= "multiply"
    ))

poem_content = "".join(elements)
div = f"<div style='{container}'>{poem_content}</div>"
html_src = html_tmpl.format(title="matters", content=div)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>matters</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <div style='position: relative;
#             margin: 40px;
#             min-height: 750px;
# ...

# %% [markdown]
# ^ I liked it looking a bit like an airplane or a bird, but with skin / wound like colors.

# %%
#tried to play around with the idea of multiple columns of the repetitions of this text where the color changes. not loving where I got but keeping this so I can come back to it with new thoughts...

words = q1.split()

def color_gradient(start_rgb, end_rgb, percent):
    r1, g1, b1 = start_rgb
    r2, g2, b2 = end_rgb
    
    r = r1 + percent * (r2 - r1)
    g = g1 + percent * (g2 - g1)
    b = b1 + percent * (b2 - b1)
    
    return f'rgb({int(r)}, {int(g)}, {int(b)})'

def create_block(x_position, height_factor=1.0, start_offset=0):
    tree_elements = []
    
    base_variations = []
    for i in range(len(words)+1):
        rotated_words = words[i:] + words[:i]
        base_variations.append(" ".join(rotated_words))
    
    repetitions = random.randint(1, 3)
    variations = base_variations * repetitions
    
    vertical_spacing = 4 * height_factor
    start_y = 50 + start_offset
    
    top_color = (46, 139, 87) 
    bottom_color = (112, 74, 47)
    
    for idx, sentence in enumerate(variations):
        percent = idx / (len(variations) - 1) if len(variations) > 1 else 0
        color = color_gradient(top_color, bottom_color, percent)
        
        tree_elements.append(mkdiv(
            sentence,
            position="absolute",
            left=f"{x_position}%",
            top=f"{start_y + idx * vertical_spacing}px",
            transform="translateX(-50%)",
            color=color,
            font_size="8px",
            letter_spacing="-0.5px",
            font_family="80-kb-g",
            background_color="transparent"
        ))
    
    return tree_elements

elements = []
num_trees = 10

start_x = 10    
end_x = 90 
x_range = end_x - start_x

for i in range(num_trees):
    x_pos = start_x + (i * x_range / (num_trees - 1))
    
    height = random.uniform(1, 5)
    offset = random.randint(-80, 40)
    
    tree = create_block(x_pos, height, offset)
    elements.extend(tree)

container = """position: relative; 
            margin: 40px; 
            min-height: 500px;
            border-radius: 50%;
            width:500px;
            background-color: #181818;
            margin-left: auto;
            margin-right: auto;
            overflow: hidden"""

poem_content = "".join(elements)
div = f"<div style='{container}'>{poem_content}</div>"
html_src = html_tmpl.format(title="forest of matters", content=div)
show_html(html_src)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <title>forest of matters</title>
#     <style>
#     html {
#         min-height: 5em;
#         overflow: hidden;
#         font-family: '80-kb', monospace;
#         font-size: 18px;
#         }
#
#     body{
#         background-color: transparent;
#     }
#
#     h1 {
#         font-weight: 400;
#     }
#
#     div{
#         background-color: transparent;
#     }
#     </style>
# </head>
# <body>
# <div style='position: relative;
#             margin: 40px;
#             min-height: 500px;
#             border-radius: 50%;
#             width:500px;
#             background-color: #181818;
#             margin-left: auto;
#             margin-right: auto;
# ...
